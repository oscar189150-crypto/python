# %% [markdown]
# |型態| 創建方式 | 可不可變 | 有序/無序 |
# |:---:|:---:|:---:|:---:|
# |list|list=[1, 2, 3]|可變|有|
# |dict| || |
# |tuple|tuple=(1, 2, 3)|不可變|有|
# |set| | | |

# %%
#不可變則需要一個新的變數去承接它
#如果不需要用舊的可以直接將舊的變數指向到新的值

# %%
#可變則不需要新的變數承接它

# %%
#建議不要把不同型別的資料放在同一個list
#同一個list只建議放一種型別的資料
