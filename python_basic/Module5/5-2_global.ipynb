# %%
# 全域變數
name = "Monkey"

# 定義函式
def rename():
    name = "kelly"

# 執行函式
rename()

# 輸出 name
print(name)
# Out:
# Monkey

# %% [markdown]
# ##### 使用 global 讓函式存取全域變數的值

# %%
# 全域變數
name = "Monkey"

# 定義函式
def rename():
    global name
    name = "Misaki"

# 執行函式
rename()

# 輸出 name
print(name)
# Out:
# Misaki
