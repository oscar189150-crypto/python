# %%
# 類別名稱
class car:
# 類別屬性 (Class Attribute)
    wheels = 4

print(car)
print(car.wheels)
# Out:
# <class '__main__.car'>
# 4

# %%
# 類別名稱
class Car:
# 類別屬性 (Class Attribute)
    wheels = 4
# 建構函式
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

# 方法 (Method)
    def show_info(self, year=2026):
        print(f"{year} {self.brand} has model - {self.model} and has {car.wheels} wheels.")
# 建立實例
car1 = Car("Toyota", "Altis")
print(car1.brand)
car1.show_info(1993)

car2 = Car("Banz", "C300")
car2.show_info()
# Out:
# Toyota
# 1993 Toyota has model - Altis and has 4 wheels.
# 2026 Banz has model - C300 and has 4 wheels.
