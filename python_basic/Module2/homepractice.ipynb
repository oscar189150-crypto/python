# %%
'''給一個字串 S ，有三種字串操作，分別如下

1. 兩兩交換：將字串內相鄰兩個字元交換，例如字串 "apcsntnu" 先分組成 (ap)(cs)(nt)(nu)，將會交換為 (pa)(sc)(tn)(un)，即得到 "pasctnun"。
2. 兩兩排序：將字串內相鄰兩個字元按照字典序排序，字元的字典序為 a < b < ... < z，例如字串 "family" 先分組成 (fa)(mi)(ly)，將會交換成 (af)(im)(ly)，即得到 "afimly"。
3. 完美重排：假設字串長度為 n ，將字串內的字元編號為 0,1,2,3,4,5,...,n-1 ，將字串分成兩半為 0,1,2,...,((n/2)-1 和 (n/2),((n/2)+1),((n/2)+1),...,n ，並且組合成 0,(n/2),1,((n/2)+1),...,((n/2)-1),n-1 。例如 "apcsntnu" 拆成 "apcs" 和 "ntnu"，然後交錯成 "anptcnsu"。

給定 K 個操作，請依序操作字串，輸出最後的字串結果。'''

# %%
a = "misaki"

def switch(a):

# %%
a = "misaki"
b = ""
for i in range(0, len(a)-1, 2):
    b += a[i+1]
    b += a[i]
print(b)
# Out:
# imasik

# %%
a = "misaki"
b = ""
c = ["a","b"]
for i in range(0, len(a)-1, 2):
    c[0] = a[i+1]
    c[1] = a[i]
    c.sort()
    b += "".join(c)
    '''
    for j in c:
        b += j
        '''
print(b)
# Out:
# imasik

# %%
a = "misaki"
b = ""
c = ["a","b"]
for i in range(0, len(a)//2):
    b += a[i]
    b += a[len(a)//2+i]
print(b)
# Out:
# maiksi
