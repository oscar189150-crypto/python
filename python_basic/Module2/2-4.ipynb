# %% [markdown]
# | | |
# |:---|:---|
# | | |

# %% [markdown]
# 算術運算子

# %%
print(8+19)
print(89-7)
print(9*4)
print(20/4)
print(100%3)
print(2**10)
print(100//3)
# Out:
# 27
# 82
# 36
# 5.0
# 1
# 1024
# 33

# %% [markdown]
# 賦值運算子

# %%
a = 8
b = 13

b += a
print(b)
# Out:
# 21

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %%
a = 17
b = 21

if a<b:
    print("True")
else:
    print("False")
    
print(a>=b)
# Out:
# True
# False

# %%
grade = 90
pass_grade = 80

if (grade>pass_grade):
    print("good")

print(grade)
# Out:
# good

# %% [markdown]
# 邏輯運算子 and / or / not

# %%
username = 88888
password = 88888

if username == 88888 and password == 88888:
    print("sucess!")
# Out:
# sucess!

# %% [markdown]
# 成員運算子 in / not in

# %%
mylist = ["A100", "A101", "A102"]
a = "A102"
if a in mylist:
    print("yes")
# Out:
# yes

# %% [markdown]
# 身分運算子 is / is not

# %%
#is 用來判斷記憶體位置

x = 100
y = 23
z = 123

print(id(x))
print(id(y))
print(id(z))
print(id(x+y))

A1 = x > y
A2 = z > y

x+y is z
A1 is A2
# Out:
# 140723559093784
# 140723559091320
# 140723559094520
# 140723559094520
# True

# %% [markdown]
# 位元運算子

# %%
print("不重要")
# Out:
# 不重要
