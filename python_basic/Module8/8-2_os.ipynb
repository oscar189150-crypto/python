# %%
import os
# 匯入套件

folder_path = "../Module7"
# 檔案路徑
files = os.listdir(folder_path)
print(files)

# 如果指定路徑的檔案存在，則執行刪除
file_path = "data.txt"
print(os.path.exists(file_path))
if os.path.exists(file_path):
    os.remove(file_path)
# Out:
# ['7-1_try_except.ipynb', '7-2_raise.ipynb', 'data.txt', 'README.md']
# False
